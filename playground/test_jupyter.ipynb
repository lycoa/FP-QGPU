# %%
from fp_qgpu import hello
from fp_qgpu.pauli_matricies import pauli_x, pauli_y

print(hello())
# Out:
# Hello from fp-qgpu!

# %%
a = pauli_x() @ pauli_y()
print(a)
# Out:
# [[0.+1.j 0.+0.j]
#  [0.+0.j 0.-1.j]]
